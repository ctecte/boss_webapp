# %%
import sqlite3
from matplotlib import pyplot as plt
import pandas as pd

db = "boss_data.db"
conn = sqlite3.connect(db)
cursor = conn.cursor()

# uncomment the code below to view table columns 
table_info = "PRAGMA table_info(boss)"
cursor.execute(table_info)
#i = 0
#for column in cursor.fetchall():
#    print(f"{i}: " + column[1])
#    i += 1

query = """
    SELECT * from boss 
    where course_code = "CS205"
    and bidding_window like "Round 1 Window 1"
    and median_bid != 0;
    """
df = pd.read_sql_query(query, conn)
conn.close()

day_order = ['MON', 'TUE', 'WED', 'THU', 'FRI']
df['day_idx'] = df['day'].apply(lambda d: day_order.index(d))
df = df.sort_values(by=['day_idx', 'start_time'])
# temp_df = df[['course_code','day','start_time']]
# print(temp_df.head(20))
df['start_time'] = df['start_time'].str.slice(0, 5)
df['end_time'] = df['end_time'].str.slice(0, 5)

df

# cursor.execute(query)
# results = cursor.fetchall()
# for data in results:
#     print(data)
# Out:
#               term                   session    bidding_window course_code  \
# 9   2024-25 Term 2  Regular Academic Session  Round 1 Window 1       CS205
# 0   2021-22 Term 2  Regular Academic Session  Round 1 Window 1       CS205
# 10  2024-25 Term 2  Regular Academic Session  Round 1 Window 1       CS205
# 1   2021-22 Term 2  Regular Academic Session  Round 1 Window 1       CS205
# 7   2023-24 Term 2  Regular Academic Session  Round 1 Window 1       CS205
# 8   2023-24 Term 2  Regular Academic Session  Round 1 Window 1       CS205
# 12  2024-25 Term 2  Regular Academic Session  Round 1 Window 1       CS205
# 3   2022-23 Term 2  Regular Academic Session  Round 1 Window 1       CS205
# 5   2023-24 Term 2  Regular Academic Session  Round 1 Window 1       CS205
# 4   2022-23 Term 2  Regular Academic Session  Round 1 Window 1       CS205
# 2   2022-23 Term 2  Regular Academic Session  Round 1 Window 1       CS205
# 6   2023-24 Term 2  Regular Academic Session  Round 1 Window 1       CS205
# 11  2024-25 Term 2  Regular Academic Session  Round 1 Window 1       CS205
#
#                                description section  vacancy  opening_vacancy  \
# 9                        Operating Systems      G1       45               35
# 0   Operating System Concepts with Android      G1       51               51
# 10                       Operating Systems      G2       45               35
# 1   Operating System Concepts with Android      G2       51               51
# 7   Operating System Concepts with Android      G3       37               37
# 8   Operating System Concepts with Android      G4       37               37
# 12                       Operating Systems      G4       45               35
# 3   Operating System Concepts with Android      G2       45               29
# 5   Operating System Concepts with Android      G1       37               37
# 4   Operating System Concepts with Android      G3       45               29
# 2   Operating System Concepts with Android      G1       45               29
# 6   Operating System Concepts with Android      G2       37               37
# 11                       Operating Systems      G3       45               35
#
#     before_process_vacancy  d.i.c.e  ...  median_bid  min_bid  \
# 9                       35        0  ...       23.88    20.00
# 0                       51        0  ...       13.50    12.46
# 10                      35        0  ...       20.00    10.11
# 1                       51        0  ...       12.12    10.02
# 7                       37        0  ...       20.73    16.03
# 8                       37        0  ...       18.69    16.11
# 12                      35        0  ...       20.21    17.00
# 3                       29        0  ...       15.71    15.00
# 5                       37        0  ...       18.48    15.51
# 4                       29        0  ...       13.21    10.15
# 2                       29        0  ...       13.51    11.01
# 6                       37        0  ...       16.89    12.06
# 11                      35        0  ...       19.94    15.32
#
#             instructor  school/department meet  day  start_time end_time  \
# 9    SWAVEK WLODKOWSKI                SIS  1.0  MON       12:00    15:15
# 0        NGO CHONG WAH                SIS  1.0  MON       15:30    18:45
# 10   SWAVEK WLODKOWSKI                SIS  1.0  MON       15:30    18:45
# 1        NGO CHONG WAH                SIS  1.0  TUE       15:30    18:45
# 7    SWAVEK WLODKOWSKI                SIS  1.0  WED       12:00    15:15
# 8    SWAVEK WLODKOWSKI                SIS  1.0  WED       15:30    18:45
# 12        TAN PANG JIN                SIS  1.0  THU       12:00    15:15
# 3        NGO CHONG WAH                SIS  1.0  THU       15:30    18:45
# 5        NGO CHONG WAH                SIS  1.0  THU       15:30    18:45
# 4    SWAVEK WLODKOWSKI                SIS  1.0  FRI       08:15    11:30
# 2        NGO CHONG WAH                SIS  1.0  FRI       12:00    15:15
# 6        NGO CHONG WAH                SIS  1.0  FRI       12:00    15:15
# 11       NGO CHONG WAH                SIS  1.0  FRI       12:00    15:15
#
#                           venue day_idx
# 9        SCIS1 Seminar Room 2-1       0
# 0        SCIS1 Seminar Room 2-4       0
# 10       SCIS1 Seminar Room 2-1       0
# 1        SCIS1 Seminar Room 2-4       1
# 7    SOE/SCIS2 Seminar Room 3-2       2
# 8    SOE/SCIS2 Seminar Room 3-2       2
# 12       SCIS1 Seminar Room 3-4       3
# 3   SOE/SCIS2 Seminar Room 2-10       3
# 5        SCIS1 Seminar Room 3-2       3
# 4        SCIS1 Seminar Room 2-1       4
# 2        SCIS1 Seminar Room 2-4       4
# 6        SCIS1 Seminar Room 3-2       4
# 11   SOE/SCIS2 Seminar Room 2-5       4
#
# [13 rows x 22 columns]
